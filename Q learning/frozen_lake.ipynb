# %%
import random
import gym
import gym.spaces
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim


HIDDEN_SIZE = 128
BATCH_SIZE = 100
PERCENTILE = 30
GAMMA = 0.9


class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)


Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])


def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor(torch.tensor(obs).unsqueeze(0))
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, _ = env.step(action)
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch, percentile):
    disc_rewards = list(map(lambda s: s.reward * (GAMMA ** len(s.steps)), batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs = []
    train_act = []
    elite_batch = []
    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation, example.steps))
            train_act.extend(map(lambda step: step.action, example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound


if __name__ == "__main__":
    random.seed(12345)
    env = DiscreteOneHotWrapper(gym.make("FrozenLake-v1"))
    # env = gym.wrappers.Monitor(env, directory="mon", force=True)
    obs_size = env.observation_space.shape[0]
    n_actions = env.action_space.n

    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.001)
    writer = SummaryWriter(comment="-frozenlake-tweaked")

    full_batch = []
    for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
        reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
        full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
        if not full_batch:
            continue
        obs_v = torch.FloatTensor(obs)
        acts_v = torch.LongTensor(acts)
        full_batch = full_batch[-500:]

        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()
        print("%d: loss=%.3f, reward_mean=%.3f, reward_bound=%.3f, batch=%d" % (
            iter_no, loss_v.item(), reward_mean, reward_bound, len(full_batch)))
        writer.add_scalar("loss", loss_v.item(), iter_no)
        writer.add_scalar("reward_mean", reward_mean, iter_no)
        writer.add_scalar("reward_bound", reward_bound, iter_no)
        if reward_mean > 0.8:
            print("Solved!")
            break
    writer.close()
# Out:
# C:\Users\An_asus\AppData\Local\Temp/ipykernel_3592/1106909425.py:107: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:210.)
#   obs_v = torch.FloatTensor(obs)
# 0: loss=1.379, reward_mean=0.030, reward_bound=0.000, batch=3
# 1: loss=1.379, reward_mean=0.010, reward_bound=0.000, batch=4
# 2: loss=1.378, reward_mean=0.010, reward_bound=0.000, batch=5
# 3: loss=1.385, reward_mean=0.050, reward_bound=0.000, batch=10
# 4: loss=1.381, reward_mean=0.010, reward_bound=0.000, batch=11
# 5: loss=1.381, reward_mean=0.030, reward_bound=0.000, batch=14
# 6: loss=1.378, reward_mean=0.040, reward_bound=0.000, batch=18
# 7: loss=1.378, reward_mean=0.020, reward_bound=0.000, batch=20
# 8: loss=1.376, reward_mean=0.000, reward_bound=0.000, batch=20
# 9: loss=1.375, reward_mean=0.000, reward_bound=0.000, batch=20
# 10: loss=1.374, reward_mean=0.010, reward_bound=0.000, batch=21
# 11: loss=1.372, reward_mean=0.020, reward_bound=0.000, batch=23
# 12: loss=1.370, reward_mean=0.020, reward_bound=0.000, batch=25
# 13: loss=1.369, reward_mean=0.010, reward_bound=0.000, batch=26
# 14: loss=1.368, reward_mean=0.000, reward_bound=0.000, batch=26
# 15: loss=1.367, reward_mean=0.010, reward_bound=0.000, batch=27
# 16: loss=1.363, reward_mean=0.040, reward_bound=0.000, batch=31
# 17: loss=1.361, reward_mean=0.020, reward_bound=0.000, batch=33
# 18: loss=1.359, reward_mean=0.010, reward_bound=0.000, batch=34
# 19: loss=1.356, reward_mean=0.010, reward_bound=0.000, batch=35
# 20: loss=1.355, reward_mean=0.000, reward_bound=0.000, batch=35
# 21: loss=1.355, reward_mean=0.010, reward_bound=0.000, batch=36
# 22: loss=1.355, reward_mean=0.020, reward_bound=0.000, batch=38
# 23: loss=1.355, reward_mean=0.020, reward_bound=0.000, batch=40
# 24: loss=1.354, reward_mean=0.010, reward_bound=0.000, batch=41
# 25: loss=1.353, reward_mean=0.010, reward_bound=0.000, batch=42
# 26: loss=1.353, reward_mean=0.020, reward_bound=0.000, batch=44
# 27: loss=1.352, reward_mean=0.030, reward_bound=0.000, batch=47
# 28: loss=1.351, reward_mean=0.000, reward_bound=0.000, batch=47
# 29: loss=1.350, reward_mean=0.010, reward_bound=0.000, batch=48
# 30: loss=1.349, reward_mean=0.010, reward_bound=0.000, batch=49
# 31: loss=1.344, reward_mean=0.050, reward_bound=0.000, batch=54
# 32: loss=1.342, reward_mean=0.010, reward_bound=0.000, batch=55
# 33: loss=1.339, reward_mean=0.060, reward_bound=0.000, batch=61
# 34: loss=1.338, reward_mean=0.020, reward_bound=0.000, batch=63
# 35: loss=1.336, reward_mean=0.020, reward_bound=0.000, batch=65
# 36: loss=1.336, reward_mean=0.010, reward_bound=0.000, batch=66
# 37: loss=1.334, reward_mean=0.020, reward_bound=0.000, batch=68
# 38: loss=1.333, reward_mean=0.000, reward_bound=0.000, batch=68
# 39: loss=1.331, reward_mean=0.020, reward_bound=0.000, batch=70
# 40: loss=1.331, reward_mean=0.030, reward_bound=0.000, batch=73
# 41: loss=1.332, reward_mean=0.010, reward_bound=0.000, batch=74
# 42: loss=1.331, reward_mean=0.070, reward_bound=0.000, batch=81
# 43: loss=1.331, reward_mean=0.010, reward_bound=0.000, batch=82
# 44: loss=1.331, reward_mean=0.010, reward_bound=0.000, batch=83
# 45: loss=1.330, reward_mean=0.040, reward_bound=0.000, batch=87
# 46: loss=1.328, reward_mean=0.010, reward_bound=0.000, batch=88
# 47: loss=1.328, reward_mean=0.000, reward_bound=0.000, batch=88
# 48: loss=1.328, reward_mean=0.060, reward_bound=0.000, batch=94
# 49: loss=1.328, reward_mean=0.040, reward_bound=0.000, batch=98
# 50: loss=1.325, reward_mean=0.020, reward_bound=0.000, batch=100
# 51: loss=1.325, reward_mean=0.010, reward_bound=0.000, batch=101
# 52: loss=1.323, reward_mean=0.020, reward_bound=0.000, batch=103
# 53: loss=1.321, reward_mean=0.030, reward_bound=0.000, batch=106
# 54: loss=1.320, reward_mean=0.010, reward_bound=0.000, batch=107
# 55: loss=1.321, reward_mean=0.020, reward_bound=0.000, batch=109
# 56: loss=1.320, reward_mean=0.000, reward_bound=0.000, batch=109
# 57: loss=1.320, reward_mean=0.070, reward_bound=0.000, batch=116
# 58: loss=1.321, reward_mean=0.030, reward_bound=0.000, batch=119
# 59: loss=1.319, reward_mean=0.050, reward_bound=0.000, batch=124
# 60: loss=1.318, reward_mean=0.040, reward_bound=0.000, batch=128
# 61: loss=1.318, reward_mean=0.020, reward_bound=0.000, batch=130
# 62: loss=1.317, reward_mean=0.010, reward_bound=0.000, batch=131
# 63: loss=1.316, reward_mean=0.040, reward_bound=0.000, batch=135
# 64: loss=1.315, reward_mean=0.050, reward_bound=0.000, batch=140
# 65: loss=1.316, reward_mean=0.060, reward_bound=0.000, batch=146
# 66: loss=1.315, reward_mean=0.010, reward_bound=0.000, batch=147
# 67: loss=1.313, reward_mean=0.020, reward_bound=0.000, batch=149
# 68: loss=1.313, reward_mean=0.020, reward_bound=0.000, batch=151
# 69: loss=1.312, reward_mean=0.040, reward_bound=0.000, batch=155
# 70: loss=1.311, reward_mean=0.040, reward_bound=0.000, batch=159
# 71: loss=1.309, reward_mean=0.020, reward_bound=0.000, batch=161
# 72: loss=1.308, reward_mean=0.020, reward_bound=0.000, batch=163
# 73: loss=1.308, reward_mean=0.010, reward_bound=0.000, batch=164
# 74: loss=1.308, reward_mean=0.040, reward_bound=0.000, batch=168
# 75: loss=1.308, reward_mean=0.020, reward_bound=0.000, batch=170
# 76: loss=1.308, reward_mean=0.010, reward_bound=0.000, batch=171
# 77: loss=1.307, reward_mean=0.020, reward_bound=0.000, batch=173
# 78: loss=1.305, reward_mean=0.030, reward_bound=0.000, batch=176
# 79: loss=1.303, reward_mean=0.020, reward_bound=0.000, batch=178
# 80: loss=1.302, reward_mean=0.030, reward_bound=0.000, batch=181
# 81: loss=1.299, reward_mean=0.040, reward_bound=0.000, batch=185
# 82: loss=1.298, reward_mean=0.040, reward_bound=0.000, batch=189
# 83: loss=1.297, reward_mean=0.040, reward_bound=0.000, batch=193
# 84: loss=1.296, reward_mean=0.030, reward_bound=0.000, batch=196
# 85: loss=1.296, reward_mean=0.010, reward_bound=0.000, batch=197
# 86: loss=1.295, reward_mean=0.040, reward_bound=0.000, batch=201
# 87: loss=1.294, reward_mean=0.030, reward_bound=0.000, batch=204
# 88: loss=1.294, reward_mean=0.030, reward_bound=0.000, batch=207
# 89: loss=1.293, reward_mean=0.030, reward_bound=0.000, batch=210
# 90: loss=1.293, reward_mean=0.040, reward_bound=0.000, batch=214
# 91: loss=1.292, reward_mean=0.030, reward_bound=0.000, batch=217
# 92: loss=1.289, reward_mean=0.030, reward_bound=0.000, batch=220
# 93: loss=1.287, reward_mean=0.050, reward_bound=0.036, batch=224
# 94: loss=1.287, reward_mean=0.000, reward_bound=0.000, batch=224
# 95: loss=1.287, reward_mean=0.020, reward_bound=0.000, batch=226
# 96: loss=1.287, reward_mean=0.030, reward_bound=0.045, batch=228
# 97: loss=1.286, reward_mean=0.040, reward_bound=0.052, batch=228
# 98: loss=1.288, reward_mean=0.040, reward_bound=0.081, batch=229
# 99: loss=1.288, reward_mean=0.010, reward_bound=0.029, batch=230
# 100: loss=1.286, reward_mean=0.030, reward_bound=0.089, batch=228
# 101: loss=1.281, reward_mean=0.050, reward_bound=0.109, batch=226
# 102: loss=1.281, reward_mean=0.000, reward_bound=0.000, batch=226
# 103: loss=1.280, reward_mean=0.010, reward_bound=0.000, batch=227
# 104: loss=1.281, reward_mean=0.030, reward_bound=0.122, batch=226
# 105: loss=1.282, reward_mean=0.050, reward_bound=0.135, batch=224
# 106: loss=1.279, reward_mean=0.050, reward_bound=0.150, batch=221
# 107: loss=1.278, reward_mean=0.030, reward_bound=0.000, batch=224
# 108: loss=1.272, reward_mean=0.060, reward_bound=0.167, batch=218
# 109: loss=1.271, reward_mean=0.020, reward_bound=0.000, batch=220
# 110: loss=1.271, reward_mean=0.030, reward_bound=0.000, batch=223
# 111: loss=1.269, reward_mean=0.040, reward_bound=0.117, batch=226
# 112: loss=1.268, reward_mean=0.010, reward_bound=0.000, batch=227
# 113: loss=1.269, reward_mean=0.010, reward_bound=0.000, batch=228
# 114: loss=1.269, reward_mean=0.020, reward_bound=0.123, batch=229
# 115: loss=1.267, reward_mean=0.040, reward_bound=0.148, batch=230
# 116: loss=1.268, reward_mean=0.020, reward_bound=0.180, batch=231
# 117: loss=1.263, reward_mean=0.040, reward_bound=0.185, batch=224
# 118: loss=1.255, reward_mean=0.050, reward_bound=0.206, batch=209
# 119: loss=1.255, reward_mean=0.040, reward_bound=0.000, batch=213
# 120: loss=1.256, reward_mean=0.060, reward_bound=0.066, batch=219
# 121: loss=1.256, reward_mean=0.040, reward_bound=0.026, batch=223
# 122: loss=1.255, reward_mean=0.020, reward_bound=0.000, batch=225
# 123: loss=1.255, reward_mean=0.060, reward_bound=0.101, batch=227
# 124: loss=1.254, reward_mean=0.020, reward_bound=0.088, batch=229
# 125: loss=1.252, reward_mean=0.030, reward_bound=0.126, batch=230
# 126: loss=1.252, reward_mean=0.030, reward_bound=0.185, batch=230
# 127: loss=1.252, reward_mean=0.020, reward_bound=0.206, batch=230
# 128: loss=1.242, reward_mean=0.060, reward_bound=0.229, batch=217
# 129: loss=1.243, reward_mean=0.010, reward_bound=0.000, batch=218
# 130: loss=1.242, reward_mean=0.050, reward_bound=0.049, batch=222
# 131: loss=1.241, reward_mean=0.030, reward_bound=0.056, batch=225
# 132: loss=1.241, reward_mean=0.020, reward_bound=0.037, batch=227
# 133: loss=1.241, reward_mean=0.050, reward_bound=0.240, batch=229
# 134: loss=1.237, reward_mean=0.030, reward_bound=0.254, batch=206
# 135: loss=1.236, reward_mean=0.020, reward_bound=0.000, batch=208
# 136: loss=1.238, reward_mean=0.030, reward_bound=0.000, batch=211
# 137: loss=1.236, reward_mean=0.030, reward_bound=0.000, batch=214
# 138: loss=1.234, reward_mean=0.050, reward_bound=0.000, batch=219
# 139: loss=1.230, reward_mean=0.060, reward_bound=0.103, batch=223
# 140: loss=1.229, reward_mean=0.050, reward_bound=0.144, batch=226
# 141: loss=1.227, reward_mean=0.030, reward_bound=0.158, batch=228
# 142: loss=1.226, reward_mean=0.050, reward_bound=0.169, batch=229
# 143: loss=1.226, reward_mean=0.030, reward_bound=0.203, batch=230
# 144: loss=1.225, reward_mean=0.060, reward_bound=0.247, batch=231
# 145: loss=1.213, reward_mean=0.060, reward_bound=0.282, batch=194
# 146: loss=1.212, reward_mean=0.090, reward_bound=0.000, batch=203
# 147: loss=1.211, reward_mean=0.040, reward_bound=0.000, batch=207
# 148: loss=1.211, reward_mean=0.020, reward_bound=0.000, batch=209
# 149: loss=1.206, reward_mean=0.050, reward_bound=0.000, batch=214
# 150: loss=1.207, reward_mean=0.020, reward_bound=0.000, batch=216
# 151: loss=1.207, reward_mean=0.050, reward_bound=0.040, batch=221
# 152: loss=1.208, reward_mean=0.030, reward_bound=0.000, batch=224
# 153: loss=1.207, reward_mean=0.020, reward_bound=0.000, batch=226
# 154: loss=1.201, reward_mean=0.060, reward_bound=0.143, batch=228
# 155: loss=1.204, reward_mean=0.070, reward_bound=0.206, batch=227
# 156: loss=1.200, reward_mean=0.090, reward_bound=0.254, batch=227
# 157: loss=1.200, reward_mean=0.020, reward_bound=0.226, batch=229
# 158: loss=1.201, reward_mean=0.040, reward_bound=0.282, batch=225
# 159: loss=1.200, reward_mean=0.030, reward_bound=0.289, batch=227
# 160: loss=1.200, reward_mean=0.050, reward_bound=0.308, batch=229
# 161: loss=1.193, reward_mean=0.040, reward_bound=0.314, batch=193
# 162: loss=1.191, reward_mean=0.020, reward_bound=0.000, batch=195
# 163: loss=1.189, reward_mean=0.030, reward_bound=0.000, batch=198
# 164: loss=1.188, reward_mean=0.050, reward_bound=0.000, batch=203
# 165: loss=1.185, reward_mean=0.050, reward_bound=0.000, batch=208
# 166: loss=1.183, reward_mean=0.030, reward_bound=0.000, batch=211
# 167: loss=1.183, reward_mean=0.050, reward_bound=0.000, batch=216
# 168: loss=1.182, reward_mean=0.060, reward_bound=0.087, batch=221
# 169: loss=1.182, reward_mean=0.100, reward_bound=0.135, batch=223
# 170: loss=1.181, reward_mean=0.050, reward_bound=0.167, batch=225
# 171: loss=1.178, reward_mean=0.050, reward_bound=0.206, batch=226
# 172: loss=1.182, reward_mean=0.030, reward_bound=0.229, batch=224
# 173: loss=1.182, reward_mean=0.100, reward_bound=0.252, batch=227
# 174: loss=1.180, reward_mean=0.040, reward_bound=0.254, batch=228
# 175: loss=1.178, reward_mean=0.050, reward_bound=0.282, batch=222
# 176: loss=1.174, reward_mean=0.040, reward_bound=0.141, batch=225
# 177: loss=1.175, reward_mean=0.060, reward_bound=0.289, batch=227
# 178: loss=1.174, reward_mean=0.070, reward_bound=0.314, batch=224
# 179: loss=1.174, reward_mean=0.020, reward_bound=0.000, batch=226
# 180: loss=1.174, reward_mean=0.000, reward_bound=0.000, batch=226
# 181: loss=1.172, reward_mean=0.020, reward_bound=0.049, batch=228
# 182: loss=1.170, reward_mean=0.010, reward_bound=0.010, batch=229
# 183: loss=1.172, reward_mean=0.050, reward_bound=0.213, batch=230
# 184: loss=1.170, reward_mean=0.050, reward_bound=0.329, batch=231
# 185: loss=1.170, reward_mean=0.010, reward_bound=0.089, batch=231
# 186: loss=1.169, reward_mean=0.040, reward_bound=0.349, batch=174
# 187: loss=1.171, reward_mean=0.080, reward_bound=0.000, batch=182
# 188: loss=1.171, reward_mean=0.110, reward_bound=0.000, batch=193
# 189: loss=1.170, reward_mean=0.060, reward_bound=0.000, batch=199
# 190: loss=1.168, reward_mean=0.070, reward_bound=0.000, batch=206
# 191: loss=1.169, reward_mean=0.050, reward_bound=0.000, batch=211
# 192: loss=1.168, reward_mean=0.100, reward_bound=0.109, batch=217
# 193: loss=1.167, reward_mean=0.040, reward_bound=0.000, batch=221
# 194: loss=1.165, reward_mean=0.090, reward_bound=0.167, batch=224
# 195: loss=1.165, reward_mean=0.060, reward_bound=0.185, batch=225
# 196: loss=1.162, reward_mean=0.030, reward_bound=0.175, batch=227
# 197: loss=1.163, reward_mean=0.020, reward_bound=0.088, batch=229
# 198: loss=1.161, reward_mean=0.050, reward_bound=0.206, batch=228
# 199: loss=1.157, reward_mean=0.080, reward_bound=0.229, batch=227
# 200: loss=1.160, reward_mean=0.070, reward_bound=0.254, batch=223
# 201: loss=1.160, reward_mean=0.020, reward_bound=0.000, batch=225
# 202: loss=1.158, reward_mean=0.030, reward_bound=0.260, batch=227
# 203: loss=1.157, reward_mean=0.060, reward_bound=0.277, batch=229
# 204: loss=1.156, reward_mean=0.030, reward_bound=0.250, batch=230
# 205: loss=1.155, reward_mean=0.060, reward_bound=0.282, batch=225
# 206: loss=1.156, reward_mean=0.050, reward_bound=0.234, batch=227
# 207: loss=1.155, reward_mean=0.040, reward_bound=0.254, batch=228
# 208: loss=1.152, reward_mean=0.060, reward_bound=0.314, batch=226
# 209: loss=1.149, reward_mean=0.060, reward_bound=0.349, batch=212
# 210: loss=1.148, reward_mean=0.060, reward_bound=0.024, batch=218
# 211: loss=1.148, reward_mean=0.030, reward_bound=0.000, batch=221
# 212: loss=1.149, reward_mean=0.060, reward_bound=0.150, batch=223
# 213: loss=1.148, reward_mean=0.060, reward_bound=0.206, batch=225
# 214: loss=1.148, reward_mean=0.030, reward_bound=0.240, batch=227
# 215: loss=1.147, reward_mean=0.010, reward_bound=0.000, batch=228
# 216: loss=1.147, reward_mean=0.020, reward_bound=0.109, batch=229
# 217: loss=1.145, reward_mean=0.020, reward_bound=0.237, batch=230
# 218: loss=1.147, reward_mean=0.040, reward_bound=0.314, batch=227
# 219: loss=1.147, reward_mean=0.030, reward_bound=0.335, batch=229
# 220: loss=1.147, reward_mean=0.050, reward_bound=0.328, batch=230
# 221: loss=1.142, reward_mean=0.060, reward_bound=0.387, batch=155
# 222: loss=1.145, reward_mean=0.040, reward_bound=0.000, batch=159
# 223: loss=1.141, reward_mean=0.060, reward_bound=0.000, batch=165
# 224: loss=1.142, reward_mean=0.030, reward_bound=0.000, batch=168
# 225: loss=1.138, reward_mean=0.070, reward_bound=0.000, batch=175
# 226: loss=1.140, reward_mean=0.100, reward_bound=0.000, batch=185
# 227: loss=1.135, reward_mean=0.070, reward_bound=0.000, batch=192
# 228: loss=1.134, reward_mean=0.020, reward_bound=0.000, batch=194
# 229: loss=1.134, reward_mean=0.030, reward_bound=0.000, batch=197
# 230: loss=1.135, reward_mean=0.050, reward_bound=0.000, batch=202
# 231: loss=1.134, reward_mean=0.020, reward_bound=0.000, batch=204
# 232: loss=1.130, reward_mean=0.030, reward_bound=0.000, batch=207
# 233: loss=1.122, reward_mean=0.110, reward_bound=0.080, batch=214
# 234: loss=1.127, reward_mean=0.040, reward_bound=0.000, batch=218
# 235: loss=1.128, reward_mean=0.070, reward_bound=0.111, batch=222
# 236: loss=1.131, reward_mean=0.070, reward_bound=0.126, batch=225
# 237: loss=1.127, reward_mean=0.070, reward_bound=0.150, batch=226
# 238: loss=1.127, reward_mean=0.070, reward_bound=0.176, batch=228
# 239: loss=1.127, reward_mean=0.030, reward_bound=0.185, batch=227
# 240: loss=1.124, reward_mean=0.070, reward_bound=0.206, batch=228
# 241: loss=1.125, reward_mean=0.050, reward_bound=0.229, batch=226
# 242: loss=1.124, reward_mean=0.040, reward_bound=0.241, batch=228
# 243: loss=1.123, reward_mean=0.040, reward_bound=0.192, batch=229
# 244: loss=1.126, reward_mean=0.070, reward_bound=0.254, batch=225
# 245: loss=1.124, reward_mean=0.020, reward_bound=0.041, batch=227
# 246: loss=1.125, reward_mean=0.010, reward_bound=0.000, batch=228
# 247: loss=1.126, reward_mean=0.050, reward_bound=0.282, batch=219
# 248: loss=1.128, reward_mean=0.040, reward_bound=0.074, batch=223
# 249: loss=1.127, reward_mean=0.090, reward_bound=0.271, batch=226
# 250: loss=1.127, reward_mean=0.000, reward_bound=0.000, batch=226
# 251: loss=1.131, reward_mean=0.060, reward_bound=0.314, batch=220
# 252: loss=1.129, reward_mean=0.070, reward_bound=0.349, batch=213
# 253: loss=1.128, reward_mean=0.030, reward_bound=0.000, batch=216
# 254: loss=1.126, reward_mean=0.020, reward_bound=0.000, batch=218
# 255: loss=1.126, reward_mean=0.060, reward_bound=0.161, batch=222
# 256: loss=1.127, reward_mean=0.060, reward_bound=0.254, batch=224
# 257: loss=1.125, reward_mean=0.080, reward_bound=0.282, batch=226
# 258: loss=1.123, reward_mean=0.050, reward_bound=0.298, batch=228
# 259: loss=1.122, reward_mean=0.050, reward_bound=0.353, batch=229
# 260: loss=1.122, reward_mean=0.070, reward_bound=0.364, batch=230
# 261: loss=1.129, reward_mean=0.070, reward_bound=0.387, batch=209
# 262: loss=1.126, reward_mean=0.070, reward_bound=0.003, batch=216
# 263: loss=1.129, reward_mean=0.040, reward_bound=0.000, batch=220
# 264: loss=1.129, reward_mean=0.040, reward_bound=0.006, batch=224
# 265: loss=1.126, reward_mean=0.040, reward_bound=0.122, batch=227
# 266: loss=1.128, reward_mean=0.060, reward_bound=0.182, batch=229
# 267: loss=1.125, reward_mean=0.080, reward_bound=0.239, batch=230
# 268: loss=1.125, reward_mean=0.030, reward_bound=0.240, batch=231
# 269: loss=1.126, reward_mean=0.020, reward_bound=0.254, batch=231
# 270: loss=1.124, reward_mean=0.080, reward_bound=0.314, batch=229
# 271: loss=1.121, reward_mean=0.080, reward_bound=0.349, batch=227
# 272: loss=1.120, reward_mean=0.020, reward_bound=0.251, batch=229
# 273: loss=1.119, reward_mean=0.070, reward_bound=0.364, batch=230
# 274: loss=1.121, reward_mean=0.090, reward_bound=0.387, batch=224
# 275: loss=1.121, reward_mean=0.050, reward_bound=0.204, batch=227
# 276: loss=1.121, reward_mean=0.090, reward_bound=0.314, batch=228
# 277: loss=1.121, reward_mean=0.080, reward_bound=0.387, batch=227
# 278: loss=1.119, reward_mean=0.010, reward_bound=0.000, batch=228
# 279: loss=1.120, reward_mean=0.060, reward_bound=0.387, batch=228
# 280: loss=1.119, reward_mean=0.040, reward_bound=0.224, batch=229
# 281: loss=1.118, reward_mean=0.050, reward_bound=0.405, batch=230
# 282: loss=1.119, reward_mean=0.080, reward_bound=0.406, batch=231
# 283: loss=1.091, reward_mean=0.070, reward_bound=0.430, batch=129
# 284: loss=1.093, reward_mean=0.080, reward_bound=0.000, batch=137
# 285: loss=1.093, reward_mean=0.090, reward_bound=0.000, batch=146
# 286: loss=1.097, reward_mean=0.060, reward_bound=0.000, batch=152
# 287: loss=1.089, reward_mean=0.090, reward_bound=0.000, batch=161
# 288: loss=1.089, reward_mean=0.110, reward_bound=0.000, batch=172
# 289: loss=1.086, reward_mean=0.070, reward_bound=0.000, batch=179
# 290: loss=1.088, reward_mean=0.020, reward_bound=0.000, batch=181
# 291: loss=1.088, reward_mean=0.030, reward_bound=0.000, batch=184
# 292: loss=1.087, reward_mean=0.080, reward_bound=0.000, batch=192
# 293: loss=1.088, reward_mean=0.030, reward_bound=0.000, batch=195
# 294: loss=1.092, reward_mean=0.050, reward_bound=0.000, batch=200
# 295: loss=1.094, reward_mean=0.090, reward_bound=0.000, batch=209
# 296: loss=1.094, reward_mean=0.060, reward_bound=0.000, batch=215
# 297: loss=1.088, reward_mean=0.080, reward_bound=0.065, batch=219
# 298: loss=1.088, reward_mean=0.050, reward_bound=0.075, batch=223
# 299: loss=1.077, reward_mean=0.070, reward_bound=0.105, batch=226
# 300: loss=1.078, reward_mean=0.070, reward_bound=0.135, batch=226
# 301: loss=1.074, reward_mean=0.110, reward_bound=0.167, batch=221
# 302: loss=1.064, reward_mean=0.110, reward_bound=0.206, batch=214
# 303: loss=1.064, reward_mean=0.080, reward_bound=0.224, batch=220
# 304: loss=1.067, reward_mean=0.090, reward_bound=0.229, batch=219
# 305: loss=1.066, reward_mean=0.080, reward_bound=0.213, batch=223
# 306: loss=1.068, reward_mean=0.020, reward_bound=0.000, batch=225
# 307: loss=1.069, reward_mean=0.040, reward_bound=0.199, batch=227
# 308: loss=1.064, reward_mean=0.060, reward_bound=0.254, batch=221
# 309: loss=1.063, reward_mean=0.030, reward_bound=0.000, batch=224
# 310: loss=1.061, reward_mean=0.030, reward_bound=0.206, batch=227
# 311: loss=1.060, reward_mean=0.040, reward_bound=0.150, batch=228
# 312: loss=1.066, reward_mean=0.080, reward_bound=0.282, batch=220
# 313: loss=1.064, reward_mean=0.060, reward_bound=0.224, batch=224
# 314: loss=1.063, reward_mean=0.030, reward_bound=0.167, batch=227
# 315: loss=1.061, reward_mean=0.070, reward_bound=0.308, batch=229
# 316: loss=1.069, reward_mean=0.070, reward_bound=0.314, batch=211
# 317: loss=1.067, reward_mean=0.040, reward_bound=0.000, batch=215
# 318: loss=1.062, reward_mean=0.060, reward_bound=0.079, batch=220
# 319: loss=1.061, reward_mean=0.060, reward_bound=0.163, batch=224
# 320: loss=1.057, reward_mean=0.060, reward_bound=0.183, batch=227
# 321: loss=1.058, reward_mean=0.090, reward_bound=0.224, batch=229
# 322: loss=1.058, reward_mean=0.040, reward_bound=0.229, batch=229
# 323: loss=1.056, reward_mean=0.050, reward_bound=0.225, batch=230
# 324: loss=1.057, reward_mean=0.010, reward_bound=0.178, batch=231
# 325: loss=1.057, reward_mean=0.010, reward_bound=0.018, batch=231
# 326: loss=1.057, reward_mean=0.010, reward_bound=0.254, batch=231
# 327: loss=1.055, reward_mean=0.080, reward_bound=0.282, batch=230
# 328: loss=1.067, reward_mean=0.060, reward_bound=0.314, batch=227
# 329: loss=1.062, reward_mean=0.100, reward_bound=0.349, batch=215
# 330: loss=1.068, reward_mean=0.060, reward_bound=0.124, batch=220
# 331: loss=1.063, reward_mean=0.050, reward_bound=0.103, batch=224
# 332: loss=1.061, reward_mean=0.040, reward_bound=0.133, batch=227
# 333: loss=1.057, reward_mean=0.080, reward_bound=0.182, batch=229
# 334: loss=1.058, reward_mean=0.050, reward_bound=0.206, batch=228
# 335: loss=1.060, reward_mean=0.070, reward_bound=0.282, batch=227
# 336: loss=1.060, reward_mean=0.110, reward_bound=0.342, batch=229
# 337: loss=1.063, reward_mean=0.090, reward_bound=0.349, batch=229
# 338: loss=1.063, reward_mean=0.040, reward_bound=0.343, batch=230
# 339: loss=1.063, reward_mean=0.070, reward_bound=0.387, batch=205
# 340: loss=1.064, reward_mean=0.050, reward_bound=0.000, batch=210
# 341: loss=1.064, reward_mean=0.100, reward_bound=0.122, batch=216
# 342: loss=1.065, reward_mean=0.030, reward_bound=0.000, batch=219
# 343: loss=1.056, reward_mean=0.090, reward_bound=0.229, batch=222
# 344: loss=1.052, reward_mean=0.020, reward_bound=0.000, batch=224
# 345: loss=1.054, reward_mean=0.060, reward_bound=0.247, batch=227
# 346: loss=1.060, reward_mean=0.080, reward_bound=0.282, batch=227
# 347: loss=1.063, reward_mean=0.040, reward_bound=0.314, batch=222
# 348: loss=1.061, reward_mean=0.080, reward_bound=0.349, batch=221
# 349: loss=1.060, reward_mean=0.080, reward_bound=0.229, batch=224
# 350: loss=1.055, reward_mean=0.040, reward_bound=0.183, batch=227
# 351: loss=1.057, reward_mean=0.080, reward_bound=0.302, batch=229
# 352: loss=1.055, reward_mean=0.100, reward_bound=0.364, batch=230
# 353: loss=1.055, reward_mean=0.080, reward_bound=0.376, batch=231
# 354: loss=1.056, reward_mean=0.060, reward_bound=0.387, batch=224
# 355: loss=1.056, reward_mean=0.090, reward_bound=0.380, batch=227
# 356: loss=1.057, reward_mean=0.060, reward_bound=0.366, batch=229
# 357: loss=1.057, reward_mean=0.040, reward_bound=0.364, batch=230
# 358: loss=1.059, reward_mean=0.080, reward_bound=0.365, batch=231
# 359: loss=1.059, reward_mean=0.060, reward_bound=0.387, batch=228
# 360: loss=1.057, reward_mean=0.040, reward_bound=0.430, batch=194
# 361: loss=1.046, reward_mean=0.070, reward_bound=0.000, batch=201
# 362: loss=1.044, reward_mean=0.090, reward_bound=0.000, batch=210
# 363: loss=1.040, reward_mean=0.060, reward_bound=0.000, batch=216
# 364: loss=1.040, reward_mean=0.010, reward_bound=0.000, batch=217
# 365: loss=1.042, reward_mean=0.040, reward_bound=0.000, batch=221
# 366: loss=1.040, reward_mean=0.030, reward_bound=0.000, batch=224
# 367: loss=1.038, reward_mean=0.060, reward_bound=0.134, batch=227
# 368: loss=1.038, reward_mean=0.050, reward_bound=0.150, batch=227
# 369: loss=1.041, reward_mean=0.080, reward_bound=0.202, batch=229
# 370: loss=1.040, reward_mean=0.070, reward_bound=0.229, batch=228
# 371: loss=1.042, reward_mean=0.060, reward_bound=0.254, batch=225
# 372: loss=1.042, reward_mean=0.070, reward_bound=0.282, batch=223
# 373: loss=1.040, reward_mean=0.070, reward_bound=0.282, batch=225
# 374: loss=1.042, reward_mean=0.040, reward_bound=0.221, batch=227
# 375: loss=1.039, reward_mean=0.030, reward_bound=0.253, batch=229
# 376: loss=1.039, reward_mean=0.030, reward_bound=0.265, batch=230
# 377: loss=1.049, reward_mean=0.100, reward_bound=0.314, batch=224
# 378: loss=1.051, reward_mean=0.070, reward_bound=0.349, batch=219
# 379: loss=1.049, reward_mean=0.120, reward_bound=0.364, batch=223
# 380: loss=1.049, reward_mean=0.070, reward_bound=0.229, batch=225
# 381: loss=1.053, reward_mean=0.050, reward_bound=0.303, batch=227
# 382: loss=1.052, reward_mean=0.070, reward_bound=0.302, batch=229
# 383: loss=1.053, reward_mean=0.050, reward_bound=0.349, batch=229
# 384: loss=1.055, reward_mean=0.140, reward_bound=0.387, batch=222
# 385: loss=1.053, reward_mean=0.080, reward_bound=0.283, batch=225
# 386: loss=1.053, reward_mean=0.080, reward_bound=0.321, batch=227
# 387: loss=1.054, reward_mean=0.120, reward_bound=0.430, batch=219
# 388: loss=1.052, reward_mean=0.060, reward_bound=0.239, batch=223
# 389: loss=1.051, reward_mean=0.070, reward_bound=0.254, batch=223
# 390: loss=1.052, reward_mean=0.040, reward_bound=0.211, batch=226
# 391: loss=1.053, reward_mean=0.120, reward_bound=0.282, batch=227
# 392: loss=1.051, reward_mean=0.040, reward_bound=0.297, batch=229
# 393: loss=1.051, reward_mean=0.030, reward_bound=0.314, batch=229
# 394: loss=1.051, reward_mean=0.070, reward_bound=0.364, batch=230
# 395: loss=1.052, reward_mean=0.050, reward_bound=0.376, batch=231
# 396: loss=1.052, reward_mean=0.030, reward_bound=0.282, batch=231
# 397: loss=1.048, reward_mean=0.060, reward_bound=0.387, batch=230
# 398: loss=1.047, reward_mean=0.050, reward_bound=0.406, batch=231
# 399: loss=1.049, reward_mean=0.060, reward_bound=0.430, batch=224
# 400: loss=1.050, reward_mean=0.060, reward_bound=0.404, batch=227
# 401: loss=1.049, reward_mean=0.070, reward_bound=0.349, batch=228
# 402: loss=1.049, reward_mean=0.030, reward_bound=0.357, batch=229
# 403: loss=1.048, reward_mean=0.030, reward_bound=0.381, batch=230
# 404: loss=1.035, reward_mean=0.090, reward_bound=0.478, batch=93
# 405: loss=1.036, reward_mean=0.060, reward_bound=0.000, batch=99
# 406: loss=1.029, reward_mean=0.040, reward_bound=0.000, batch=103
# 407: loss=1.027, reward_mean=0.080, reward_bound=0.000, batch=111
# 408: loss=1.030, reward_mean=0.050, reward_bound=0.000, batch=116
# 409: loss=1.029, reward_mean=0.060, reward_bound=0.000, batch=122
# 410: loss=1.028, reward_mean=0.010, reward_bound=0.000, batch=123
# 411: loss=1.025, reward_mean=0.060, reward_bound=0.000, batch=129
# 412: loss=1.026, reward_mean=0.110, reward_bound=0.000, batch=140
# 413: loss=1.023, reward_mean=0.120, reward_bound=0.000, batch=152
# 414: loss=1.020, reward_mean=0.060, reward_bound=0.000, batch=158
# 415: loss=1.020, reward_mean=0.030, reward_bound=0.000, batch=161
# 416: loss=1.021, reward_mean=0.060, reward_bound=0.000, batch=167
# 417: loss=1.022, reward_mean=0.080, reward_bound=0.000, batch=175
# 418: loss=1.022, reward_mean=0.070, reward_bound=0.000, batch=182
# 419: loss=1.019, reward_mean=0.060, reward_bound=0.000, batch=188
# 420: loss=1.016, reward_mean=0.060, reward_bound=0.000, batch=194
# 421: loss=1.018, reward_mean=0.090, reward_bound=0.000, batch=203
# 422: loss=1.018, reward_mean=0.080, reward_bound=0.000, batch=211
# 423: loss=1.020, reward_mean=0.040, reward_bound=0.000, batch=215
# 424: loss=1.013, reward_mean=0.050, reward_bound=0.005, batch=220
# 425: loss=1.004, reward_mean=0.080, reward_bound=0.046, batch=224
# 426: loss=1.003, reward_mean=0.040, reward_bound=0.052, batch=227
# 427: loss=1.003, reward_mean=0.070, reward_bound=0.080, batch=228
# 428: loss=1.004, reward_mean=0.100, reward_bound=0.122, batch=227
# 429: loss=1.002, reward_mean=0.070, reward_bound=0.167, batch=226
# 430: loss=0.992, reward_mean=0.070, reward_bound=0.185, batch=225
# 431: loss=0.992, reward_mean=0.060, reward_bound=0.206, batch=218
# 432: loss=0.993, reward_mean=0.050, reward_bound=0.026, batch=222
# 433: loss=0.991, reward_mean=0.110, reward_bound=0.198, batch=225
# 434: loss=0.992, reward_mean=0.060, reward_bound=0.229, batch=220
# 435: loss=0.988, reward_mean=0.070, reward_bound=0.254, batch=210
# 436: loss=0.985, reward_mean=0.070, reward_bound=0.105, batch=217
# 437: loss=0.986, reward_mean=0.040, reward_bound=0.000, batch=221
# 438: loss=0.983, reward_mean=0.070, reward_bound=0.150, batch=224
# 439: loss=0.987, reward_mean=0.070, reward_bound=0.226, batch=227
# 440: loss=0.987, reward_mean=0.060, reward_bound=0.272, batch=229
# 441: loss=0.989, reward_mean=0.050, reward_bound=0.282, batch=214
# 442: loss=0.985, reward_mean=0.070, reward_bound=0.224, batch=220
# 443: loss=0.988, reward_mean=0.100, reward_bound=0.254, batch=223
# 444: loss=0.986, reward_mean=0.070, reward_bound=0.236, batch=226
# 445: loss=0.986, reward_mean=0.070, reward_bound=0.298, batch=228
# 446: loss=0.986, reward_mean=0.040, reward_bound=0.314, batch=209
# 447: loss=0.986, reward_mean=0.040, reward_bound=0.000, batch=213
# 448: loss=0.982, reward_mean=0.060, reward_bound=0.039, batch=219
# 449: loss=0.980, reward_mean=0.050, reward_bound=0.051, batch=223
# 450: loss=0.986, reward_mean=0.050, reward_bound=0.098, batch=225
# 451: loss=0.986, reward_mean=0.060, reward_bound=0.145, batch=227
# 452: loss=0.992, reward_mean=0.120, reward_bound=0.249, batch=229
# 453: loss=0.990, reward_mean=0.100, reward_bound=0.282, batch=229
# 454: loss=0.990, reward_mean=0.060, reward_bound=0.314, batch=228
# 455: loss=0.994, reward_mean=0.100, reward_bound=0.349, batch=199
# 456: loss=0.996, reward_mean=0.060, reward_bound=0.000, batch=205
# 457: loss=0.995, reward_mean=0.050, reward_bound=0.000, batch=210
# 458: loss=0.999, reward_mean=0.070, reward_bound=0.041, batch=217
# 459: loss=1.000, reward_mean=0.130, reward_bound=0.163, batch=222
# 460: loss=0.996, reward_mean=0.080, reward_bound=0.213, batch=225
# 461: loss=0.994, reward_mean=0.040, reward_bound=0.194, batch=227
# 462: loss=0.994, reward_mean=0.050, reward_bound=0.229, batch=227
# 463: loss=0.990, reward_mean=0.090, reward_bound=0.254, batch=223
# 464: loss=0.988, reward_mean=0.040, reward_bound=0.282, batch=224
# 465: loss=0.984, reward_mean=0.040, reward_bound=0.202, batch=227
# 466: loss=0.987, reward_mean=0.060, reward_bound=0.277, batch=229
# 467: loss=0.990, reward_mean=0.060, reward_bound=0.314, batch=225
# 468: loss=0.991, reward_mean=0.040, reward_bound=0.211, batch=227
# 469: loss=0.990, reward_mean=0.080, reward_bound=0.314, batch=228
# 470: loss=0.988, reward_mean=0.050, reward_bound=0.264, batch=229
# 471: loss=0.993, reward_mean=0.070, reward_bound=0.349, batch=225
# 472: loss=0.991, reward_mean=0.030, reward_bound=0.138, batch=227
# 473: loss=0.996, reward_mean=0.060, reward_bound=0.224, batch=229
# 474: loss=0.989, reward_mean=0.050, reward_bound=0.314, batch=228
# 475: loss=0.993, reward_mean=0.100, reward_bound=0.387, batch=188
# 476: loss=0.990, reward_mean=0.080, reward_bound=0.000, batch=196
# 477: loss=0.990, reward_mean=0.070, reward_bound=0.000, batch=203
# 478: loss=0.986, reward_mean=0.050, reward_bound=0.000, batch=208
# 479: loss=0.985, reward_mean=0.050, reward_bound=0.000, batch=213
# 480: loss=0.982, reward_mean=0.050, reward_bound=0.000, batch=218
# 481: loss=0.977, reward_mean=0.050, reward_bound=0.035, batch=222
# 482: loss=0.975, reward_mean=0.090, reward_bound=0.122, batch=223
# 483: loss=0.974, reward_mean=0.040, reward_bound=0.135, batch=224
# 484: loss=0.981, reward_mean=0.050, reward_bound=0.150, batch=226
# 485: loss=0.983, reward_mean=0.060, reward_bound=0.206, batch=227
# 486: loss=0.987, reward_mean=0.020, reward_bound=0.052, batch=229
# 487: loss=0.978, reward_mean=0.070, reward_bound=0.229, batch=226
# 488: loss=0.979, reward_mean=0.060, reward_bound=0.254, batch=226
# 489: loss=0.978, reward_mean=0.050, reward_bound=0.256, batch=228
# 490: loss=0.982, reward_mean=0.110, reward_bound=0.314, batch=221
# 491: loss=0.980, reward_mean=0.060, reward_bound=0.314, batch=224
# 492: loss=0.978, reward_mean=0.070, reward_bound=0.349, batch=222
# 493: loss=0.976, reward_mean=0.070, reward_bound=0.272, batch=225
# 494: loss=0.977, reward_mean=0.070, reward_bound=0.321, batch=227
# 495: loss=0.975, reward_mean=0.070, reward_bound=0.342, batch=229
# 496: loss=0.975, reward_mean=0.060, reward_bound=0.282, batch=229
# 497: loss=0.977, reward_mean=0.080, reward_bound=0.387, batch=222
# 498: loss=0.978, reward_mean=0.070, reward_bound=0.324, batch=225
# 499: loss=0.979, reward_mean=0.090, reward_bound=0.321, batch=227
# 500: loss=0.979, reward_mean=0.080, reward_bound=0.422, batch=229
# 501: loss=0.979, reward_mean=0.040, reward_bound=0.364, batch=230
# 502: loss=0.979, reward_mean=0.080, reward_bound=0.418, batch=231
# 503: loss=0.979, reward_mean=0.080, reward_bound=0.387, batch=231
# 504: loss=0.979, reward_mean=0.060, reward_bound=0.387, batch=231
# 505: loss=0.981, reward_mean=0.100, reward_bound=0.430, batch=172
# 506: loss=0.974, reward_mean=0.060, reward_bound=0.000, batch=178
# 507: loss=0.973, reward_mean=0.060, reward_bound=0.000, batch=184
# 508: loss=0.976, reward_mean=0.060, reward_bound=0.000, batch=190
# 509: loss=0.981, reward_mean=0.020, reward_bound=0.000, batch=192
# 510: loss=0.983, reward_mean=0.080, reward_bound=0.000, batch=200
# 511: loss=0.984, reward_mean=0.090, reward_bound=0.000, batch=209
# 512: loss=0.984, reward_mean=0.060, reward_bound=0.000, batch=215
# 513: loss=0.978, reward_mean=0.060, reward_bound=0.057, batch=220
# 514: loss=0.977, reward_mean=0.100, reward_bound=0.162, batch=224
# 515: loss=0.974, reward_mean=0.080, reward_bound=0.165, batch=227
# 516: loss=0.979, reward_mean=0.050, reward_bound=0.167, batch=228
# 517: loss=0.980, reward_mean=0.130, reward_bound=0.229, batch=226
# 518: loss=0.983, reward_mean=0.080, reward_bound=0.268, batch=228
# 519: loss=0.982, reward_mean=0.080, reward_bound=0.282, batch=223
# 520: loss=0.975, reward_mean=0.130, reward_bound=0.314, batch=220
# 521: loss=0.975, reward_mean=0.080, reward_bound=0.282, batch=223
# 522: loss=0.975, reward_mean=0.130, reward_bound=0.335, batch=226
# 523: loss=0.973, reward_mean=0.060, reward_bound=0.316, batch=228
# 524: loss=0.971, reward_mean=0.080, reward_bound=0.349, batch=212
# 525: loss=0.975, reward_mean=0.100, reward_bound=0.254, batch=217
# 526: loss=0.971, reward_mean=0.050, reward_bound=0.042, batch=222
# 527: loss=0.968, reward_mean=0.070, reward_bound=0.156, batch=225
# 528: loss=0.972, reward_mean=0.050, reward_bound=0.254, batch=226
# 529: loss=0.974, reward_mean=0.120, reward_bound=0.331, batch=228
# 530: loss=0.969, reward_mean=0.030, reward_bound=0.349, batch=227
# 531: loss=0.968, reward_mean=0.060, reward_bound=0.277, batch=229
# 532: loss=0.967, reward_mean=0.050, reward_bound=0.295, batch=230
# 533: loss=0.971, reward_mean=0.090, reward_bound=0.376, batch=231
# 534: loss=0.975, reward_mean=0.030, reward_bound=0.387, batch=205
# 535: loss=0.974, reward_mean=0.040, reward_bound=0.000, batch=209
# 536: loss=0.975, reward_mean=0.070, reward_bound=0.039, batch=216
# 537: loss=0.975, reward_mean=0.080, reward_bound=0.185, batch=219
# 538: loss=0.975, reward_mean=0.020, reward_bound=0.000, batch=221
# 539: loss=0.962, reward_mean=0.080, reward_bound=0.229, batch=223
# 540: loss=0.962, reward_mean=0.050, reward_bound=0.314, batch=222
# 541: loss=0.968, reward_mean=0.110, reward_bound=0.349, batch=217
# 542: loss=0.966, reward_mean=0.040, reward_bound=0.000, batch=221
# 543: loss=0.966, reward_mean=0.030, reward_bound=0.000, batch=224
# 544: loss=0.967, reward_mean=0.100, reward_bound=0.249, batch=227
# 545: loss=0.963, reward_mean=0.070, reward_bound=0.308, batch=229
# 546: loss=0.963, reward_mean=0.100, reward_bound=0.349, batch=226
# 547: loss=0.966, reward_mean=0.060, reward_bound=0.387, batch=222
# 548: loss=0.968, reward_mean=0.040, reward_bound=0.174, batch=225
# 549: loss=0.968, reward_mean=0.060, reward_bound=0.321, batch=227
# 550: loss=0.966, reward_mean=0.060, reward_bound=0.349, batch=228
# 551: loss=0.965, reward_mean=0.060, reward_bound=0.392, batch=229
# 552: loss=0.966, reward_mean=0.100, reward_bound=0.343, batch=230
# 553: loss=0.965, reward_mean=0.050, reward_bound=0.376, batch=231
# 554: loss=0.966, reward_mean=0.110, reward_bound=0.387, batch=231
# 555: loss=0.969, reward_mean=0.070, reward_bound=0.430, batch=205
# 556: loss=0.962, reward_mean=0.070, reward_bound=0.000, batch=212
# 557: loss=0.961, reward_mean=0.050, reward_bound=0.000, batch=217
# 558: loss=0.962, reward_mean=0.070, reward_bound=0.148, batch=222
# 559: loss=0.963, reward_mean=0.090, reward_bound=0.263, batch=225
# 560: loss=0.962, reward_mean=0.060, reward_bound=0.282, batch=223
# 561: loss=0.961, reward_mean=0.050, reward_bound=0.261, batch=226
# 562: loss=0.962, reward_mean=0.020, reward_bound=0.141, batch=228
# 563: loss=0.960, reward_mean=0.050, reward_bound=0.286, batch=229
# 564: loss=0.960, reward_mean=0.050, reward_bound=0.314, batch=226
# 565: loss=0.960, reward_mean=0.050, reward_bound=0.349, batch=223
# 566: loss=0.957, reward_mean=0.040, reward_bound=0.121, batch=226
# 567: loss=0.957, reward_mean=0.080, reward_bound=0.241, batch=228
# 568: loss=0.958, reward_mean=0.100, reward_bound=0.317, batch=229
# 569: loss=0.960, reward_mean=0.040, reward_bound=0.349, batch=227
# 570: loss=0.967, reward_mean=0.060, reward_bound=0.387, batch=221
# 571: loss=0.964, reward_mean=0.070, reward_bound=0.282, batch=224
# 572: loss=0.963, reward_mean=0.010, reward_bound=0.000, batch=225
# 573: loss=0.967, reward_mean=0.100, reward_bound=0.430, batch=217
# 574: loss=0.967, reward_mean=0.070, reward_bound=0.168, batch=222
# 575: loss=0.967, reward_mean=0.040, reward_bound=0.191, batch=225
# 576: loss=0.964, reward_mean=0.040, reward_bound=0.210, batch=227
# 577: loss=0.969, reward_mean=0.050, reward_bound=0.277, batch=229
# 578: loss=0.969, reward_mean=0.050, reward_bound=0.167, batch=229
# 579: loss=0.966, reward_mean=0.040, reward_bound=0.282, batch=229
# 580: loss=0.964, reward_mean=0.060, reward_bound=0.314, batch=229
# 581: loss=0.967, reward_mean=0.040, reward_bound=0.349, batch=224
# 582: loss=0.965, reward_mean=0.080, reward_bound=0.342, batch=227
# 583: loss=0.962, reward_mean=0.060, reward_bound=0.309, batch=229
# 584: loss=0.971, reward_mean=0.050, reward_bound=0.387, batch=226
# 585: loss=0.970, reward_mean=0.080, reward_bound=0.409, batch=228
# 586: loss=0.969, reward_mean=0.110, reward_bound=0.387, batch=228
# 587: loss=0.969, reward_mean=0.060, reward_bound=0.392, batch=229
# 588: loss=0.970, reward_mean=0.070, reward_bound=0.405, batch=230
# 589: loss=0.969, reward_mean=0.100, reward_bound=0.430, batch=225
# 590: loss=0.969, reward_mean=0.130, reward_bound=0.406, batch=227
# 591: loss=0.972, reward_mean=0.130, reward_bound=0.342, batch=229
# 592: loss=0.973, reward_mean=0.100, reward_bound=0.309, batch=230
# 593: loss=0.974, reward_mean=0.060, reward_bound=0.329, batch=231
# 594: loss=0.967, reward_mean=0.040, reward_bound=0.387, batch=230
# 595: loss=0.968, reward_mean=0.110, reward_bound=0.464, batch=231
# 596: loss=0.992, reward_mean=0.060, reward_bound=0.478, batch=157
# 597: loss=0.988, reward_mean=0.020, reward_bound=0.000, batch=159
# 598: loss=0.988, reward_mean=0.060, reward_bound=0.000, batch=165
# 599: loss=0.990, reward_mean=0.120, reward_bound=0.000, batch=177
# 600: loss=0.986, reward_mean=0.100, reward_bound=0.000, batch=187
# 601: loss=0.985, reward_mean=0.110, reward_bound=0.000, batch=198
# 602: loss=0.990, reward_mean=0.100, reward_bound=0.005, batch=208
# 603: loss=0.992, reward_mean=0.060, reward_bound=0.000, batch=214
# 604: loss=0.996, reward_mean=0.100, reward_bound=0.108, batch=220
# 605: loss=0.996, reward_mean=0.090, reward_bound=0.167, batch=221
# 606: loss=0.999, reward_mean=0.070, reward_bound=0.185, batch=223
# 607: loss=0.988, reward_mean=0.070, reward_bound=0.206, batch=224
# 608: loss=0.997, reward_mean=0.100, reward_bound=0.229, batch=223
# 609: loss=0.999, reward_mean=0.090, reward_bound=0.254, batch=221
# 610: loss=0.997, reward_mean=0.030, reward_bound=0.000, batch=224
# 611: loss=0.995, reward_mean=0.060, reward_bound=0.223, batch=227
# 612: loss=0.990, reward_mean=0.100, reward_bound=0.282, batch=224
# 613: loss=0.997, reward_mean=0.090, reward_bound=0.314, batch=218
# 614: loss=0.994, reward_mean=0.060, reward_bound=0.126, batch=222
# 615: loss=0.995, reward_mean=0.010, reward_bound=0.000, batch=223
# 616: loss=0.994, reward_mean=0.080, reward_bound=0.244, batch=226
# 617: loss=0.994, reward_mean=0.030, reward_bound=0.182, batch=228
# 618: loss=0.985, reward_mean=0.120, reward_bound=0.349, batch=221
# 619: loss=0.984, reward_mean=0.090, reward_bound=0.254, batch=224
# 620: loss=0.981, reward_mean=0.040, reward_bound=0.149, batch=227
# 621: loss=0.982, reward_mean=0.170, reward_bound=0.387, batch=212
# 622: loss=0.979, reward_mean=0.070, reward_bound=0.145, batch=218
# 623: loss=0.987, reward_mean=0.080, reward_bound=0.192, batch=222
# 624: loss=0.988, reward_mean=0.060, reward_bound=0.236, batch=225
# 625: loss=0.988, reward_mean=0.080, reward_bound=0.260, batch=227
# 626: loss=0.979, reward_mean=0.090, reward_bound=0.314, batch=227
# 627: loss=0.983, reward_mean=0.070, reward_bound=0.349, batch=226
# 628: loss=0.982, reward_mean=0.100, reward_bound=0.351, batch=228
# 629: loss=0.977, reward_mean=0.060, reward_bound=0.387, batch=225
# 630: loss=0.979, reward_mean=0.120, reward_bound=0.365, batch=227
# 631: loss=0.980, reward_mean=0.050, reward_bound=0.263, batch=229
# 632: loss=0.979, reward_mean=0.070, reward_bound=0.405, batch=230
# 633: loss=0.981, reward_mean=0.090, reward_bound=0.430, batch=200
# 634: loss=0.977, reward_mean=0.080, reward_bound=0.000, batch=208
# 635: loss=0.978, reward_mean=0.060, reward_bound=0.000, batch=214
# 636: loss=0.977, reward_mean=0.090, reward_bound=0.108, batch=220
# 637: loss=0.978, reward_mean=0.070, reward_bound=0.157, batch=224
# 638: loss=0.975, reward_mean=0.090, reward_bound=0.226, batch=227
# 639: loss=0.974, reward_mean=0.070, reward_bound=0.229, batch=226
# 640: loss=0.974, reward_mean=0.030, reward_bound=0.254, batch=226
# 641: loss=0.975, reward_mean=0.070, reward_bound=0.268, batch=228
# 642: loss=0.972, reward_mean=0.060, reward_bound=0.314, batch=220
# 643: loss=0.970, reward_mean=0.090, reward_bound=0.329, batch=224
# 644: loss=0.967, reward_mean=0.130, reward_bound=0.349, batch=225
# 645: loss=0.967, reward_mean=0.070, reward_bound=0.266, batch=227
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3592/1106909425.py in <module>
#     100
#     101     full_batch = []
# --> 102     for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
#     103         reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
#     104         full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
#
# ~\AppData\Local\Temp/ipykernel_3592/1106909425.py in iterate_batches(env, net, batch_size)
#      53     sm = nn.Softmax(dim=1)
#      54     while True:
# ---> 55         obs_v = torch.FloatTensor(torch.tensor(obs).unsqueeze(0))
#      56         act_probs_v = sm(net(obs_v))
#      57         act_probs = act_probs_v.data.numpy()[0]
#
# KeyboardInterrupt:
